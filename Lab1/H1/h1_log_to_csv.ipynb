# %% [markdown]
# ## Level_base_log_data

# %%
import csv
import re
import os

log_dir = "./level_base_log_data"
csv_output_path = "./h1_base_output.csv"

filename_pattern = r"h1_(\w+)_cs(\d+)_size(\d+)_base(\d+).log"

target_keys = [
    "rocksdb.number.keys.written",
    "rocksdb.bytes.written",
    "rocksdb.compact.write.bytes",
    "rocksdb.flush.write.bytes",
    "rocksdb.wal.bytes",
    "rocksdb.write.wal",
]

target_workloads = ["fillrandom", "overwrite"]

with open(csv_output_path, mode="w", newline='') as csvfile:
    writer = csv.writer(csvfile)
    header = ["workload", "compaction_style", "value_size", "max_bytes_for_level_base"] + target_keys

    for w in target_workloads:
        header += [
            f"{w}_latency_us", 
            f"{w}_throughput_ops", 
            f"{w}_throughput_bytes"
        ]

    writer.writerow(header)

    for log_file_name in os.listdir(log_dir):
        if not log_file_name.endswith(".log"):
            continue

        match = re.match(filename_pattern, log_file_name)
        if not match:
            print(f"파일 이름 형식이 올바르지 않아 건너뜀: {log_file_name}")
            continue

        workload = match.group(1)
        compaction_style = int(match.group(2))
        value_size = int(match.group(3))
        max_bytes_for_level_base = int(match.group(4))

        stats_dict = {key: None for key in target_keys}
        latency_throughput = {w: {"lat": None, "ops": None, "bytes": None} for w in target_workloads}
        log_file_path = os.path.join(log_dir, log_file_name)

        with open(log_file_path, "r") as f:
            for line in f:
                line = line.strip()

                match_count = re.match(r"(rocksdb\.[\w\.]+)\s+COUNT\s*:\s*(\d+)", line)
                if match_count:
                    key = match_count.group(1)
                    value = int(match_count.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value
                    continue

                match_avg = re.match(r"(rocksdb\.[\w\.]+)\s+AVG\s*:\s*([\d\.]+)", line)
                if match_avg:
                    key = match_avg.group(1)
                    value = float(match_avg.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value

                # Latency / Throughput 정보 추출
                for w in target_workloads:
                    if w in line:
                        match_perf = re.search(
                            r"([\d\.]+)\s+micros/op\s+([\d\.]+)\s+ops/sec.*?([\d\.]+)\s+MB/s", line
                        )
                        if match_perf:
                            latency_throughput[w]["lat"] = float(match_perf.group(1))
                            latency_throughput[w]["ops"] = float(match_perf.group(2))
                            latency_throughput[w]["bytes"] = float(match_perf.group(3))

        stat_values = [stats_dict[key] if stats_dict[key] is not None else "" for key in target_keys]

        # latency/throughput 값 추가
        latency_values = []
        for w in target_workloads:
            lt = latency_throughput[w]
            latency_values += [
                lt["lat"] if lt["lat"] is not None else "",
                lt["ops"] if lt["ops"] is not None else "",
                lt["bytes"] if lt["bytes"] is not None else "",
            ]

        row = [workload, compaction_style, value_size, max_bytes_for_level_base] + stat_values + latency_values
        writer.writerow(row)

print("CSV 저장이 완료되었습니다.")
# Out:
# CSV 저장이 완료되었습니다.

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv("./h1_base_output.csv")

# workload, compaction_style 기준 정렬
df_sorted = df.sort_values(by=["workload", "compaction_style"])

# 정렬된 데이터프레임 출력
df_sorted
# Out:
#       workload  compaction_style  value_size  max_bytes_for_level_base  \
# 2   fillrandom                 0       16384                 536870912
# 5   fillrandom                 0        4096                 268435456
# 6   fillrandom                 0        1024                  67108864
# 7   fillrandom                 0        1024                 536870912
# 8   fillrandom                 0        1024                 268435456
# 9   fillrandom                 0       16384                  67108864
# 10  fillrandom                 0        4096                 536870912
# 13  fillrandom                 0       16384                 268435456
# 16  fillrandom                 0        4096                  67108864
# 0    overwrite                 0        4096                  67108864
# 1    overwrite                 0        4096                 268435456
# 3    overwrite                 0        4096                 536870912
# 4    overwrite                 0        1024                 536870912
# 11   overwrite                 0       16384                 536870912
# 12   overwrite                 0        1024                  67108864
# 14   overwrite                 0       16384                  67108864
# 15   overwrite                 0        1024                 268435456
# 17   overwrite                 0       16384                 268435456
#
#     rocksdb.number.keys.written  rocksdb.bytes.written  \
# 2                       1000000            16417000000
# 5                       1000000             4128000000
# 6                       1000000             1056000000
# 7                       1000000             1056000000
# 8                       1000000             1056000000
# 9                       1000000            16417000000
# 10                      1000000             4128000000
# 13                      1000000            16417000000
# 16                      1000000             4128000000
# 0                       1000000             4128000000
# 1                       1000000             4128000000
# 3                       1000000             4128000000
# 4                       1000000             1056000000
# 11                      1000000            16417000000
# 12                      1000000             1056000000
# 14                      1000000            16417000000
# 15                      1000000             1056000000
# 17                      1000000            16417000000
#
#     rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 2                   36052092660                 8996302229        16417000000
# 5                    4003270522                 2301632341         4128000000
# 6                     657101850                  554147546         1056000000
# 7                     588671433                  554175641         1056000000
# 8                     612860902                  554235912         1056000000
# 9                   27054478941                 8996874388        16417000000
# 10                   4390431402                 2301548443         4128000000
# 13                  29512061896                 8997147451        16417000000
# 16                   3625923549                 2264390085         4128000000
# 0                    3624640394                 2264460227         4128000000
# 1                    3926898292                 2301346485         4128000000
# 3                    4394162603                 2301497226         4128000000
# 4                     578140401                  554188512         1056000000
# 11                  35711830951                 8997355246        16417000000
# 12                    616212692                  554147906         1056000000
# 14                  28758806652                 9033100267        16417000000
# 15                    586670980                  554101456         1056000000
# 17                  28906731543                 8996900767        16417000000
#
#     rocksdb.write.wal  fillrandom_latency_us  fillrandom_throughput_ops  \
# 2             1000000                437.744                     2284.0
# 5             1000000                 57.195                    17484.0
# 6             1000000                 16.308                    61319.0
# 7             1000000                 16.580                    60312.0
# 8             1000000                 15.947                    62707.0
# 9             1000000                373.762                     2675.0
# 10            1000000                 58.202                    17181.0
# 13            1000000                468.074                     2136.0
# 16            1000000                 75.279                    13283.0
# 0             1000000                    NaN                        NaN
# 1             1000000                    NaN                        NaN
# 3             1000000                    NaN                        NaN
# 4             1000000                    NaN                        NaN
# 11            1000000                    NaN                        NaN
# 12            1000000                    NaN                        NaN
# 14            1000000                    NaN                        NaN
# 15            1000000                    NaN                        NaN
# 17            1000000                    NaN                        NaN
#
#     fillrandom_throughput_bytes  overwrite_latency_us  \
# 2                          35.7                   NaN
# 5                          68.6                   NaN
# 6                          60.8                   NaN
# 7                          59.8                   NaN
# 8                          62.2                   NaN
# 9                          41.8                   NaN
# 10                         67.4                   NaN
# 13                         33.4                   NaN
# 16                         52.1                   NaN
# 0                           NaN                56.711
# 1                           NaN                65.895
# 3                           NaN                68.297
# 4                           NaN                17.691
# 11                          NaN               471.106
# 12                          NaN                17.641
# 14                          NaN               409.450
# 15                          NaN                17.173
# 17                          NaN               392.455
#
#     overwrite_throughput_ops  overwrite_throughput_bytes
# 2                        NaN                         NaN
# 5                        NaN                         NaN
# 6                        NaN                         NaN
# 7                        NaN                         NaN
# 8                        NaN                         NaN
# 9                        NaN                         NaN
# 10                       NaN                         NaN
# 13                       NaN                         NaN
# 16                       NaN                         NaN
# 0                    17633.0                        69.1
# 1                    15175.0                        59.5
# 3                    14641.0                        57.4
# 4                    56527.0                        56.1
# 11                    2122.0                        33.2
# 12                   56684.0                        56.2
# 14                    2442.0                        38.2
# 15                   58230.0                        57.8
# 17                    2548.0                        39.9

# %%
import pandas as pd

df_waf = df.copy()

# compaction_style 매핑
style_map = {0: 'leveled', 1: 'universal'}
df_waf['compaction_style'] = df['compaction_style'].map(style_map)

# value_size 매핑
value_size_map = {1024: '1KB', 4096: '4KB', 16384: '16KB'}
df_waf['value_size'] = df['value_size'].map(value_size_map)

# max_bytes_for_level_multiplier 매핑
max_bytes_map = {67108864: '64MB', 268435456: '256MB', 536870912: '512MB'}
df_waf['max_bytes_for_level_base'] = df['max_bytes_for_level_base'].map(max_bytes_map)

# WAF 계산: wal.bytes가 0인 경우는 NaN 처리
df_waf['WAF'] = df.apply(
    lambda row: (row['rocksdb.flush.write.bytes'] + row['rocksdb.compact.write.bytes'] + row['rocksdb.bytes.written']) / row['rocksdb.bytes.written'],
    axis=1
)

# _latency_us 컬럼들을 하나로 합치기
latency_columns = [col for col in df_waf.columns if '_latency_us' in col]
df_waf['latency'] = df_waf[latency_columns].sum(axis=1)  # 합산 예시

# _throughput_ops 컬럼들을 하나로 합치기
throughput_ops_columns = [col for col in df_waf.columns if '_throughput_ops' in col]
df_waf['throughput_ops'] = df_waf[throughput_ops_columns].sum(axis=1)  # 합산 예시

# _throughput_bytes 컬럼들을 하나로 합치기
throughput_bytes_columns = [col for col in df_waf.columns if '_throughput_bytes' in col]
df_waf['throughput_bytes'] = df_waf[throughput_bytes_columns].sum(axis=1)  # 합산 예시

# 기존 컬럼들 삭제
df_waf.drop(columns=latency_columns + throughput_ops_columns + throughput_bytes_columns, inplace=True)


# 결과 저장 (선택)
df_waf.to_csv('modified_h1_base_output.csv', index=False)

# %%
# workload, compaction_style 기준 정렬
df_waf_sorted = df_waf.sort_values(by=["workload", "compaction_style"])
df_waf_sorted
# Out:
#       workload compaction_style value_size max_bytes_for_level_base  \
# 2   fillrandom          leveled       16KB                    512MB
# 5   fillrandom          leveled        4KB                    256MB
# 6   fillrandom          leveled        1KB                     64MB
# 7   fillrandom          leveled        1KB                    512MB
# 8   fillrandom          leveled        1KB                    256MB
# 9   fillrandom          leveled       16KB                     64MB
# 10  fillrandom          leveled        4KB                    512MB
# 13  fillrandom          leveled       16KB                    256MB
# 16  fillrandom          leveled        4KB                     64MB
# 0    overwrite          leveled        4KB                     64MB
# 1    overwrite          leveled        4KB                    256MB
# 3    overwrite          leveled        4KB                    512MB
# 4    overwrite          leveled        1KB                    512MB
# 11   overwrite          leveled       16KB                    512MB
# 12   overwrite          leveled        1KB                     64MB
# 14   overwrite          leveled       16KB                     64MB
# 15   overwrite          leveled        1KB                    256MB
# 17   overwrite          leveled       16KB                    256MB
#
#     rocksdb.number.keys.written  rocksdb.bytes.written  \
# 2                       1000000            16417000000
# 5                       1000000             4128000000
# 6                       1000000             1056000000
# 7                       1000000             1056000000
# 8                       1000000             1056000000
# 9                       1000000            16417000000
# 10                      1000000             4128000000
# 13                      1000000            16417000000
# 16                      1000000             4128000000
# 0                       1000000             4128000000
# 1                       1000000             4128000000
# 3                       1000000             4128000000
# 4                       1000000             1056000000
# 11                      1000000            16417000000
# 12                      1000000             1056000000
# 14                      1000000            16417000000
# 15                      1000000             1056000000
# 17                      1000000            16417000000
#
#     rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 2                   36052092660                 8996302229        16417000000
# 5                    4003270522                 2301632341         4128000000
# 6                     657101850                  554147546         1056000000
# 7                     588671433                  554175641         1056000000
# 8                     612860902                  554235912         1056000000
# 9                   27054478941                 8996874388        16417000000
# 10                   4390431402                 2301548443         4128000000
# 13                  29512061896                 8997147451        16417000000
# 16                   3625923549                 2264390085         4128000000
# 0                    3624640394                 2264460227         4128000000
# 1                    3926898292                 2301346485         4128000000
# 3                    4394162603                 2301497226         4128000000
# 4                     578140401                  554188512         1056000000
# 11                  35711830951                 8997355246        16417000000
# 12                    616212692                  554147906         1056000000
# 14                  28758806652                 9033100267        16417000000
# 15                    586670980                  554101456         1056000000
# 17                  28906731543                 8996900767        16417000000
#
#     rocksdb.write.wal       WAF  latency  throughput_ops  throughput_bytes
# 2             1000000  3.744009  437.744          2284.0              35.7
# 5             1000000  2.527350   57.195         17484.0              68.6
# 6             1000000  2.147016   16.308         61319.0              60.8
# 7             1000000  2.082242   16.580         60312.0              59.8
# 8             1000000  2.105205   15.947         62707.0              62.2
# 9             1000000  3.195977  373.762          2675.0              41.8
# 10            1000000  2.621119   58.202         17181.0              67.4
# 13            1000000  3.345691  468.074          2136.0              33.4
# 16            1000000  2.426917   75.279         13283.0              52.1
# 0             1000000  2.426623   56.711         17633.0              69.1
# 1             1000000  2.508780   65.895         15175.0              59.5
# 3             1000000  2.622011   68.297         14641.0              57.4
# 4             1000000  2.072281   17.691         56527.0              56.1
# 11            1000000  3.723347  471.106          2122.0              33.2
# 12            1000000  2.108296   17.641         56684.0              56.2
# 14            1000000  3.301998  409.450          2442.0              38.2
# 15            1000000  2.080277   17.173         58230.0              57.8
# 17            1000000  3.308804  392.455          2548.0              39.9

# %% [markdown]
# ## Level_multiplier_log_data

# %%
import csv
import re
import os

log_dir = "./level_multiplier_log_data"
csv_output_path = "./h1_multiplier_output.csv"

filename_pattern = r"h1_(\w+)_cs(\d+)_size(\d+)_multiplier(\d+).log"

target_keys = [
    "rocksdb.number.keys.written",
    "rocksdb.bytes.written",
    "rocksdb.compact.write.bytes",
    "rocksdb.flush.write.bytes",
    "rocksdb.wal.bytes",
    "rocksdb.write.wal",
]

target_workloads = ["fillrandom", "overwrite"]

with open(csv_output_path, mode="w", newline='') as csvfile:
    writer = csv.writer(csvfile)
    header = ["workload", "compaction_style", "value_size", "max_bytes_for_level_base"] + target_keys

    for w in target_workloads:
        header += [
            f"{w}_latency_us", 
            f"{w}_throughput_ops", 
            f"{w}_throughput_bytes"
        ]

    writer.writerow(header)

    for log_file_name in os.listdir(log_dir):
        if not log_file_name.endswith(".log"):
            continue

        match = re.match(filename_pattern, log_file_name)
        if not match:
            print(f"파일 이름 형식이 올바르지 않아 건너뜀: {log_file_name}")
            continue

        workload = match.group(1)
        compaction_style = int(match.group(2))
        value_size = int(match.group(3))
        max_bytes_for_level_base = int(match.group(4))

        stats_dict = {key: None for key in target_keys}
        latency_throughput = {w: {"lat": None, "ops": None, "bytes": None} for w in target_workloads}
        log_file_path = os.path.join(log_dir, log_file_name)

        with open(log_file_path, "r") as f:
            for line in f:
                line = line.strip()

                match_count = re.match(r"(rocksdb\.[\w\.]+)\s+COUNT\s*:\s*(\d+)", line)
                if match_count:
                    key = match_count.group(1)
                    value = int(match_count.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value
                    continue

                match_avg = re.match(r"(rocksdb\.[\w\.]+)\s+AVG\s*:\s*([\d\.]+)", line)
                if match_avg:
                    key = match_avg.group(1)
                    value = float(match_avg.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value

                # Latency / Throughput 정보 추출
                for w in target_workloads:
                    if w in line:
                        match_perf = re.search(
                            r"([\d\.]+)\s+micros/op\s+([\d\.]+)\s+ops/sec.*?([\d\.]+)\s+MB/s", line
                        )
                        if match_perf:
                            latency_throughput[w]["lat"] = float(match_perf.group(1))
                            latency_throughput[w]["ops"] = float(match_perf.group(2))
                            latency_throughput[w]["bytes"] = float(match_perf.group(3))

        stat_values = [stats_dict[key] if stats_dict[key] is not None else "" for key in target_keys]

        # latency/throughput 값 추가
        latency_values = []
        for w in target_workloads:
            lt = latency_throughput[w]
            latency_values += [
                lt["lat"] if lt["lat"] is not None else "",
                lt["ops"] if lt["ops"] is not None else "",
                lt["bytes"] if lt["bytes"] is not None else "",
            ]

        row = [workload, compaction_style, value_size, max_bytes_for_level_base] + stat_values + latency_values
        writer.writerow(row)

print("CSV 저장이 완료되었습니다.")
# Out:
# CSV 저장이 완료되었습니다.

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv("./h1_multiplier_output.csv")

# workload, compaction_style 기준 정렬
df_sorted = df.sort_values(by=["workload", "compaction_style"])

# 정렬된 데이터프레임 출력
df_sorted
# Out:
#       workload  compaction_style  value_size  max_bytes_for_level_base  \
# 1   fillrandom                 0        1024                        10
# 2   fillrandom                 0       16384                        10
# 4   fillrandom                 0       16384                        20
# 5   fillrandom                 0       16384                         4
# 7   fillrandom                 0        4096                        10
# 11  fillrandom                 0        1024                        20
# 13  fillrandom                 0        4096                         4
# 14  fillrandom                 0        4096                        20
# 17  fillrandom                 0        1024                         4
# 0    overwrite                 0        4096                        20
# 3    overwrite                 0       16384                        20
# 6    overwrite                 0       16384                        10
# 8    overwrite                 0        4096                         4
# 9    overwrite                 0        1024                         4
# 10   overwrite                 0       16384                         4
# 12   overwrite                 0        1024                        10
# 15   overwrite                 0        4096                        10
# 16   overwrite                 0        1024                        20
#
#     rocksdb.number.keys.written  rocksdb.bytes.written  \
# 1                       1000000             1056000000
# 2                       1000000            16417000000
# 4                       1000000            16417000000
# 5                       1000000            16417000000
# 7                       1000000             4128000000
# 11                      1000000             1056000000
# 13                      1000000             4128000000
# 14                      1000000             4128000000
# 17                      1000000             1056000000
# 0                       1000000             4128000000
# 3                       1000000            16417000000
# 6                       1000000            16417000000
# 8                       1000000             4128000000
# 9                       1000000             1056000000
# 10                      1000000            16417000000
# 12                      1000000             1056000000
# 15                      1000000             4128000000
# 16                      1000000             1056000000
#
#     rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 1                     532065061                  554231834         1056000000
# 2                   26808615703                 8996537425        16417000000
# 4                   28859522575                 8996966203        16417000000
# 5                   26312224465                 8997182632        16417000000
# 7                    3668790542                 2264613878         4128000000
# 11                    573779355                  554231337         1056000000
# 13                   3961650233                 2263893245         4128000000
# 14                   3812224142                 2264247445         4128000000
# 17                    518053266                  554174033         1056000000
# 0                    3876164853                 2264551781         4128000000
# 3                   26975184186                 8996918853        16417000000
# 6                   27856641055                 8996908575        16417000000
# 8                    3778744523                 2301775935         4128000000
# 9                     581516485                  554180812         1056000000
# 10                  26371740694                 8996164758        16417000000
# 12                    581280026                  554114156         1056000000
# 15                   3727609108                 2301265466         4128000000
# 16                    584544657                  554146613         1056000000
#
#     rocksdb.write.wal  fillrandom_latency_us  fillrandom_throughput_ops  \
# 1             1000000                 12.622                    79224.0
# 2             1000000                410.739                     2434.0
# 4             1000000                458.188                     2182.0
# 5             1000000                397.332                     2516.0
# 7             1000000                 71.569                    13972.0
# 11            1000000                 14.197                    70438.0
# 13            1000000                 72.693                    13756.0
# 14            1000000                 79.614                    12560.0
# 17            1000000                 14.077                    71038.0
# 0             1000000                    NaN                        NaN
# 3             1000000                    NaN                        NaN
# 6             1000000                    NaN                        NaN
# 8             1000000                    NaN                        NaN
# 9             1000000                    NaN                        NaN
# 10            1000000                    NaN                        NaN
# 12            1000000                    NaN                        NaN
# 15            1000000                    NaN                        NaN
# 16            1000000                    NaN                        NaN
#
#     fillrandom_throughput_bytes  overwrite_latency_us  \
# 1                          78.6                   NaN
# 2                          38.1                   NaN
# 4                          34.1                   NaN
# 5                          39.4                   NaN
# 7                          54.8                   NaN
# 11                         69.9                   NaN
# 13                         53.9                   NaN
# 14                         49.3                   NaN
# 17                         70.5                   NaN
# 0                           NaN                77.384
# 3                           NaN               447.835
# 6                           NaN               386.952
# 8                           NaN                68.390
# 9                           NaN                14.194
# 10                          NaN               411.400
# 12                          NaN                12.704
# 15                          NaN                69.845
# 16                          NaN                15.645
#
#     overwrite_throughput_ops  overwrite_throughput_bytes
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 4                        NaN                         NaN
# 5                        NaN                         NaN
# 7                        NaN                         NaN
# 11                       NaN                         NaN
# 13                       NaN                         NaN
# 14                       NaN                         NaN
# 17                       NaN                         NaN
# 0                    12922.0                        50.7
# 3                     2232.0                        34.9
# 6                     2584.0                        40.4
# 8                    14621.0                        57.3
# 9                    70449.0                        69.9
# 10                    2430.0                        38.0
# 12                   78717.0                        78.1
# 15                   14317.0                        56.1
# 16                   63918.0                        63.4

# %%
import pandas as pd

df_waf = df.copy()

# compaction_style 매핑
style_map = {0: 'leveled', 1: 'universal'}
df_waf['compaction_style'] = df['compaction_style'].map(style_map)

# value_size 매핑
value_size_map = {1024: '1KB', 4096: '4KB', 16384: '16KB'}
df_waf['value_size'] = df['value_size'].map(value_size_map)

# WAF 계산: wal.bytes가 0인 경우는 NaN 처리
df_waf['WAF'] = df.apply(
    lambda row: (row['rocksdb.flush.write.bytes'] + row['rocksdb.compact.write.bytes'] + row['rocksdb.bytes.written']) / row['rocksdb.bytes.written'],
    axis=1
)

# _latency_us 컬럼들을 하나로 합치기
latency_columns = [col for col in df_waf.columns if '_latency_us' in col]
df_waf['latency'] = df_waf[latency_columns].sum(axis=1)  # 합산 예시

# _throughput_ops 컬럼들을 하나로 합치기
throughput_ops_columns = [col for col in df_waf.columns if '_throughput_ops' in col]
df_waf['throughput_ops'] = df_waf[throughput_ops_columns].sum(axis=1)  # 합산 예시

# _throughput_bytes 컬럼들을 하나로 합치기
throughput_bytes_columns = [col for col in df_waf.columns if '_throughput_bytes' in col]
df_waf['throughput_bytes'] = df_waf[throughput_bytes_columns].sum(axis=1)  # 합산 예시

# 기존 컬럼들 삭제
df_waf.drop(columns=latency_columns + throughput_ops_columns + throughput_bytes_columns, inplace=True)

# 결과 저장 (선택)
df_waf.to_csv('modified_h1_multiplier_output.csv', index=False)

# %%
# workload, compaction_style 기준 정렬
df_waf_sorted = df_waf.sort_values(by=["workload", "compaction_style"])
df_waf_sorted
# Out:
#       workload compaction_style value_size  max_bytes_for_level_base  \
# 1   fillrandom          leveled        1KB                        10
# 2   fillrandom          leveled       16KB                        10
# 4   fillrandom          leveled       16KB                        20
# 5   fillrandom          leveled       16KB                         4
# 7   fillrandom          leveled        4KB                        10
# 11  fillrandom          leveled        1KB                        20
# 13  fillrandom          leveled        4KB                         4
# 14  fillrandom          leveled        4KB                        20
# 17  fillrandom          leveled        1KB                         4
# 0    overwrite          leveled        4KB                        20
# 3    overwrite          leveled       16KB                        20
# 6    overwrite          leveled       16KB                        10
# 8    overwrite          leveled        4KB                         4
# 9    overwrite          leveled        1KB                         4
# 10   overwrite          leveled       16KB                         4
# 12   overwrite          leveled        1KB                        10
# 15   overwrite          leveled        4KB                        10
# 16   overwrite          leveled        1KB                        20
#
#     rocksdb.number.keys.written  rocksdb.bytes.written  \
# 1                       1000000             1056000000
# 2                       1000000            16417000000
# 4                       1000000            16417000000
# 5                       1000000            16417000000
# 7                       1000000             4128000000
# 11                      1000000             1056000000
# 13                      1000000             4128000000
# 14                      1000000             4128000000
# 17                      1000000             1056000000
# 0                       1000000             4128000000
# 3                       1000000            16417000000
# 6                       1000000            16417000000
# 8                       1000000             4128000000
# 9                       1000000             1056000000
# 10                      1000000            16417000000
# 12                      1000000             1056000000
# 15                      1000000             4128000000
# 16                      1000000             1056000000
#
#     rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 1                     532065061                  554231834         1056000000
# 2                   26808615703                 8996537425        16417000000
# 4                   28859522575                 8996966203        16417000000
# 5                   26312224465                 8997182632        16417000000
# 7                    3668790542                 2264613878         4128000000
# 11                    573779355                  554231337         1056000000
# 13                   3961650233                 2263893245         4128000000
# 14                   3812224142                 2264247445         4128000000
# 17                    518053266                  554174033         1056000000
# 0                    3876164853                 2264551781         4128000000
# 3                   26975184186                 8996918853        16417000000
# 6                   27856641055                 8996908575        16417000000
# 8                    3778744523                 2301775935         4128000000
# 9                     581516485                  554180812         1056000000
# 10                  26371740694                 8996164758        16417000000
# 12                    581280026                  554114156         1056000000
# 15                   3727609108                 2301265466         4128000000
# 16                    584544657                  554146613         1056000000
#
#     rocksdb.write.wal       WAF  latency  throughput_ops  throughput_bytes
# 1             1000000  2.028690   12.622         79224.0              78.6
# 2             1000000  3.180980  410.739          2434.0              38.1
# 4             1000000  3.305932  458.188          2182.0              34.1
# 5             1000000  3.150783  397.332          2516.0              39.4
# 7             1000000  2.437356   71.569         13972.0              54.8
# 11            1000000  2.068192   14.197         70438.0              69.9
# 13            1000000  2.508126   72.693         13756.0              53.9
# 14            1000000  2.472013   79.614         12560.0              49.3
# 17            1000000  2.015367   14.077         71038.0              70.5
# 0             1000000  2.487577   77.384         12922.0              50.7
# 3             1000000  3.191150  447.835          2232.0              34.9
# 6             1000000  3.244841  386.952          2584.0              40.4
# 8             1000000  2.472994   68.390         14621.0              57.3
# 9             1000000  2.075471   14.194         70449.0              69.9
# 10            1000000  3.154346  411.400          2430.0              38.0
# 12            1000000  2.075184   12.704         78717.0              78.1
# 15            1000000  2.460483   69.845         14317.0              56.1
# 16            1000000  2.078306   15.645         63918.0              63.4

# %% [markdown]
# ## Leveled Log

# %%
import csv
import re
import os

log_dir = "./leveled_log_data"
csv_output_path = "./h1_leveled_output.csv"

# 정규표현식을 이용해 파일 이름에서 정보 추출
filename_pattern = r"h1_(\w+)_cs(\d+)_size(\d+).log"

target_keys = [
    "rocksdb.number.keys.written",
    "rocksdb.bytes.written",
    "rocksdb.compact.write.bytes",
    "rocksdb.flush.write.bytes",
    "rocksdb.wal.bytes",
    "rocksdb.write.wal",
]

target_workloads = ["fillrandom", "overwrite"]

with open(csv_output_path, mode="w", newline='') as csvfile:
    writer = csv.writer(csvfile)
    header = ["workload", "compaction_style", "value_size", "max_bytes_for_level_base"] + target_keys

    for w in target_workloads:
        header += [
            f"{w}_latency_us", 
            f"{w}_throughput_ops", 
            f"{w}_throughput_bytes"
        ]

    writer.writerow(header)

    for log_file_name in os.listdir(log_dir):
        if not log_file_name.endswith(".log"):
            continue

        match = re.match(filename_pattern, log_file_name)
        if not match:
            print(f"파일 이름 형식이 올바르지 않아 건너뜀: {log_file_name}")
            continue

        workload = match.group(1)
        compaction_style = int(match.group(2))
        value_size = int(match.group(3))

        stats_dict = {key: None for key in target_keys}
        latency_throughput = {w: {"lat": None, "ops": None, "bytes": None} for w in target_workloads}
        log_file_path = os.path.join(log_dir, log_file_name)

        with open(log_file_path, "r") as f:
            for line in f:
                line = line.strip()

                match_count = re.match(r"(rocksdb\.[\w\.]+)\s+COUNT\s*:\s*(\d+)", line)
                if match_count:
                    key = match_count.group(1)
                    value = int(match_count.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value
                    continue

                match_avg = re.match(r"(rocksdb\.[\w\.]+)\s+AVG\s*:\s*([\d\.]+)", line)
                if match_avg:
                    key = match_avg.group(1)
                    value = float(match_avg.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value

                # Latency / Throughput 정보 추출
                for w in target_workloads:
                    if w in line:
                        match_perf = re.search(
                            r"([\d\.]+)\s+micros/op\s+([\d\.]+)\s+ops/sec.*?([\d\.]+)\s+MB/s", line
                        )
                        if match_perf:
                            latency_throughput[w]["lat"] = float(match_perf.group(1))
                            latency_throughput[w]["ops"] = float(match_perf.group(2))
                            latency_throughput[w]["bytes"] = float(match_perf.group(3))

        stat_values = [stats_dict[key] if stats_dict[key] is not None else "" for key in target_keys]

        # latency/throughput 값 추가
        latency_values = []
        for w in target_workloads:
            lt = latency_throughput[w]
            latency_values += [
                lt["lat"] if lt["lat"] is not None else "",
                lt["ops"] if lt["ops"] is not None else "",
                lt["bytes"] if lt["bytes"] is not None else "",
            ]

        row = [workload, compaction_style, value_size, max_bytes_for_level_base] + stat_values + latency_values
        writer.writerow(row)

print("CSV 저장이 완료되었습니다.")
# Out:
# CSV 저장이 완료되었습니다.

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv("./h1_leveled_output.csv")

# workload, compaction_style 기준 정렬
df_sorted = df.sort_values(by=["workload", "compaction_style"])

# 정렬된 데이터프레임 출력
df_sorted
# Out:
#      workload  compaction_style  value_size  max_bytes_for_level_base  \
# 1  fillrandom                 0       16384                         4
# 4  fillrandom                 0        4096                         4
# 5  fillrandom                 0        1024                         4
# 0   overwrite                 0        1024                         4
# 2   overwrite                 0        4096                         4
# 3   overwrite                 0       16384                         4
#
#    rocksdb.number.keys.written  rocksdb.bytes.written  \
# 1                          NaN                    NaN
# 4                    1000000.0           4.128000e+09
# 5                    1000000.0           1.056000e+09
# 0                    1000000.0           1.056000e+09
# 2                    1000000.0           4.128000e+09
# 3                          NaN                    NaN
#
#    rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 1                          NaN                        NaN                NaN
# 4                 3.392791e+09               2.264426e+09       4.128000e+09
# 5                 5.263365e+08               5.541926e+08       1.056000e+09
# 0                 5.423216e+08               5.542331e+08       1.056000e+09
# 2                 3.402204e+09               2.264465e+09       4.128000e+09
# 3                          NaN                        NaN                NaN
#
#    rocksdb.write.wal  fillrandom_latency_us  fillrandom_throughput_ops  \
# 1                NaN                    NaN                        NaN
# 4          1000000.0                 76.668                    13043.0
# 5          1000000.0                 17.585                    56838.0
# 0          1000000.0                    NaN                        NaN
# 2          1000000.0                    NaN                        NaN
# 3                NaN                    NaN                        NaN
#
#    fillrandom_throughput_bytes  overwrite_latency_us  \
# 1                          NaN                   NaN
# 4                         51.1                   NaN
# 5                         56.4                   NaN
# 0                          NaN                20.251
# 2                          NaN                63.033
# 3                          NaN                   NaN
#
#    overwrite_throughput_ops  overwrite_throughput_bytes
# 1                       NaN                         NaN
# 4                       NaN                         NaN
# 5                       NaN                         NaN
# 0                   49349.0                        48.9
# 2                   15864.0                        62.2
# 3                       NaN                         NaN

# %%
import pandas as pd

df_waf = df.copy()

# compaction_style 매핑
style_map = {0: 'leveled', 1: 'universal'}
df_waf['compaction_style'] = df['compaction_style'].map(style_map)

# value_size 매핑
value_size_map = {1024: '1KB', 4096: '4KB', 16384: '16KB'}
df_waf['value_size'] = df['value_size'].map(value_size_map)

# WAF 계산: wal.bytes가 0인 경우는 NaN 처리
df_waf['WAF'] = df.apply(
    lambda row: (row['rocksdb.flush.write.bytes'] + row['rocksdb.compact.write.bytes'] + row['rocksdb.bytes.written']) / row['rocksdb.bytes.written'],
    axis=1
)

# _latency_us 컬럼들을 하나로 합치기
latency_columns = [col for col in df_waf.columns if '_latency_us' in col]
df_waf['latency'] = df_waf[latency_columns].sum(axis=1)  # 합산 예시

# _throughput_ops 컬럼들을 하나로 합치기
throughput_ops_columns = [col for col in df_waf.columns if '_throughput_ops' in col]
df_waf['throughput_ops'] = df_waf[throughput_ops_columns].sum(axis=1)  # 합산 예시

# _throughput_bytes 컬럼들을 하나로 합치기
throughput_bytes_columns = [col for col in df_waf.columns if '_throughput_bytes' in col]
df_waf['throughput_bytes'] = df_waf[throughput_bytes_columns].sum(axis=1)  # 합산 예시

# 기존 컬럼들 삭제
df_waf.drop(columns=latency_columns + throughput_ops_columns + throughput_bytes_columns, inplace=True)

# 결과 저장 (선택)
df_waf.to_csv('modified_h1_leveled_output.csv', index=False)

# %%
# workload, compaction_style 기준 정렬
df_waf_sorted = df_waf.sort_values(by=["workload", "compaction_style"])
df_waf_sorted
# Out:
#      workload compaction_style value_size  max_bytes_for_level_base  \
# 1  fillrandom          leveled       16KB                         4
# 4  fillrandom          leveled        4KB                         4
# 5  fillrandom          leveled        1KB                         4
# 0   overwrite          leveled        1KB                         4
# 2   overwrite          leveled        4KB                         4
# 3   overwrite          leveled       16KB                         4
#
#    rocksdb.number.keys.written  rocksdb.bytes.written  \
# 1                          NaN                    NaN
# 4                    1000000.0           4.128000e+09
# 5                    1000000.0           1.056000e+09
# 0                    1000000.0           1.056000e+09
# 2                    1000000.0           4.128000e+09
# 3                          NaN                    NaN
#
#    rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 1                          NaN                        NaN                NaN
# 4                 3.392791e+09               2.264426e+09       4.128000e+09
# 5                 5.263365e+08               5.541926e+08       1.056000e+09
# 0                 5.423216e+08               5.542331e+08       1.056000e+09
# 2                 3.402204e+09               2.264465e+09       4.128000e+09
# 3                          NaN                        NaN                NaN
#
#    rocksdb.write.wal       WAF  latency  throughput_ops  throughput_bytes
# 1                NaN       NaN    0.000             0.0               0.0
# 4          1000000.0  2.370450   76.668         13043.0              51.1
# 5          1000000.0  2.023228   17.585         56838.0              56.4
# 0          1000000.0  2.038404   20.251         49349.0              48.9
# 2          1000000.0  2.372740   63.033         15864.0              62.2
# 3                NaN       NaN    0.000             0.0               0.0

# %% [markdown]
# ## Universal Log

# %%
import csv
import re
import os

log_dir = "./universal_log_data"
csv_output_path = "./h1_universal_output.csv"

# 정규표현식을 이용해 파일 이름에서 정보 추출
filename_pattern = r"h1_(\w+)_cs(\d+)_size(\d+).log"

target_keys = [
    "rocksdb.number.keys.written",
    "rocksdb.bytes.written",
    "rocksdb.compact.write.bytes",
    "rocksdb.flush.write.bytes",
    "rocksdb.wal.bytes",
    "rocksdb.write.wal",
]

target_workloads = ["fillrandom", "overwrite"]

with open(csv_output_path, mode="w", newline='') as csvfile:
    writer = csv.writer(csvfile)
    header = ["workload", "compaction_style", "value_size", "max_bytes_for_level_base"] + target_keys

    for w in target_workloads:
        header += [
            f"{w}_latency_us", 
            f"{w}_throughput_ops", 
            f"{w}_throughput_bytes"
        ]

    writer.writerow(header)

    for log_file_name in os.listdir(log_dir):
        if not log_file_name.endswith(".log"):
            continue

        match = re.match(filename_pattern, log_file_name)
        if not match:
            print(f"파일 이름 형식이 올바르지 않아 건너뜀: {log_file_name}")
            continue

        workload = match.group(1)
        compaction_style = int(match.group(2))
        value_size = int(match.group(3))

        stats_dict = {key: None for key in target_keys}
        latency_throughput = {w: {"lat": None, "ops": None, "bytes": None} for w in target_workloads}
        log_file_path = os.path.join(log_dir, log_file_name)

        with open(log_file_path, "r") as f:
            for line in f:
                line = line.strip()

                match_count = re.match(r"(rocksdb\.[\w\.]+)\s+COUNT\s*:\s*(\d+)", line)
                if match_count:
                    key = match_count.group(1)
                    value = int(match_count.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value
                    continue

                match_avg = re.match(r"(rocksdb\.[\w\.]+)\s+AVG\s*:\s*([\d\.]+)", line)
                if match_avg:
                    key = match_avg.group(1)
                    value = float(match_avg.group(2))
                    if key in stats_dict:
                        stats_dict[key] = value

                # Latency / Throughput 정보 추출
                for w in target_workloads:
                    if w in line:
                        match_perf = re.search(
                            r"([\d\.]+)\s+micros/op\s+([\d\.]+)\s+ops/sec.*?([\d\.]+)\s+MB/s", line
                        )
                        if match_perf:
                            latency_throughput[w]["lat"] = float(match_perf.group(1))
                            latency_throughput[w]["ops"] = float(match_perf.group(2))
                            latency_throughput[w]["bytes"] = float(match_perf.group(3))

        stat_values = [stats_dict[key] if stats_dict[key] is not None else "" for key in target_keys]

        # latency/throughput 값 추가
        latency_values = []
        for w in target_workloads:
            lt = latency_throughput[w]
            latency_values += [
                lt["lat"] if lt["lat"] is not None else "",
                lt["ops"] if lt["ops"] is not None else "",
                lt["bytes"] if lt["bytes"] is not None else "",
            ]

        row = [workload, compaction_style, value_size, max_bytes_for_level_base] + stat_values + latency_values
        writer.writerow(row)

print("CSV 저장이 완료되었습니다.")
# Out:
# CSV 저장이 완료되었습니다.

# %%
import pandas as pd

# CSV 파일 읽기
df = pd.read_csv("./h1_universal_output.csv")

# workload, compaction_style 기준 정렬
df_sorted = df.sort_values(by=["workload", "compaction_style"])

# 정렬된 데이터프레임 출력
df_sorted
# Out:
#      workload  compaction_style  value_size  max_bytes_for_level_base  \
# 1  fillrandom                 1        4096                         4
# 3  fillrandom                 1       16384                         4
# 4  fillrandom                 1        1024                         4
# 0   overwrite                 1        1024                         4
# 2   overwrite                 1       16384                         4
# 5   overwrite                 1        4096                         4
#
#    rocksdb.number.keys.written  rocksdb.bytes.written  \
# 1                      1000000             4128000000
# 3                      1000000            16417000000
# 4                      1000000             1056000000
# 0                      1000000             1056000000
# 2                      1000000            16417000000
# 5                      1000000             4128000000
#
#    rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 1                   3540818396                 2301488797         4128000000
# 3                  23330374011                 8996719499        16417000000
# 4                    590356007                  554189559         1056000000
# 0                    589472628                  554212973         1056000000
# 2                  20922566009                 8996726917        16417000000
# 5                   3254281401                 2263874391         4128000000
#
#    rocksdb.write.wal  fillrandom_latency_us  fillrandom_throughput_ops  \
# 1            1000000                 74.644                    13396.0
# 3            1000000                344.567                     2902.0
# 4            1000000                 13.143                    76087.0
# 0            1000000                    NaN                        NaN
# 2            1000000                    NaN                        NaN
# 5            1000000                    NaN                        NaN
#
#    fillrandom_throughput_bytes  overwrite_latency_us  \
# 1                         52.5                   NaN
# 3                         45.4                   NaN
# 4                         75.5                   NaN
# 0                          NaN                13.732
# 2                          NaN               315.428
# 5                          NaN                61.157
#
#    overwrite_throughput_ops  overwrite_throughput_bytes
# 1                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# 0                   72819.0                        72.2
# 2                    3170.0                        49.6
# 5                   16351.0                        64.1

# %%
import pandas as pd

df_waf = df.copy()

# compaction_style 매핑
style_map = {0: 'leveled', 1: 'universal'}
df_waf['compaction_style'] = df['compaction_style'].map(style_map)

# value_size 매핑
value_size_map = {1024: '1KB', 4096: '4KB', 16384: '16KB'}
df_waf['value_size'] = df['value_size'].map(value_size_map)

# WAF 계산: wal.bytes가 0인 경우는 NaN 처리
df_waf['WAF'] = df.apply(
    lambda row: (row['rocksdb.flush.write.bytes'] + row['rocksdb.compact.write.bytes'] + row['rocksdb.bytes.written']) / row['rocksdb.bytes.written'],
    axis=1
)

# _latency_us 컬럼들을 하나로 합치기
latency_columns = [col for col in df_waf.columns if '_latency_us' in col]
df_waf['latency'] = df_waf[latency_columns].sum(axis=1)  # 합산 예시

# _throughput_ops 컬럼들을 하나로 합치기
throughput_ops_columns = [col for col in df_waf.columns if '_throughput_ops' in col]
df_waf['throughput_ops'] = df_waf[throughput_ops_columns].sum(axis=1)  # 합산 예시

# _throughput_bytes 컬럼들을 하나로 합치기
throughput_bytes_columns = [col for col in df_waf.columns if '_throughput_bytes' in col]
df_waf['throughput_bytes'] = df_waf[throughput_bytes_columns].sum(axis=1)  # 합산 예시

# 기존 컬럼들 삭제
df_waf.drop(columns=latency_columns + throughput_ops_columns + throughput_bytes_columns, inplace=True)

# 결과 저장 (선택)
df_waf.to_csv('modified_h1_universal_output.csv', index=False)

# %%
# workload, compaction_style 기준 정렬
df_waf_sorted = df_waf.sort_values(by=["workload", "compaction_style"])
df_waf_sorted
# Out:
#      workload compaction_style value_size  max_bytes_for_level_base  \
# 1  fillrandom        universal        4KB                         4
# 3  fillrandom        universal       16KB                         4
# 4  fillrandom        universal        1KB                         4
# 0   overwrite        universal        1KB                         4
# 2   overwrite        universal       16KB                         4
# 5   overwrite        universal        4KB                         4
#
#    rocksdb.number.keys.written  rocksdb.bytes.written  \
# 1                      1000000             4128000000
# 3                      1000000            16417000000
# 4                      1000000             1056000000
# 0                      1000000             1056000000
# 2                      1000000            16417000000
# 5                      1000000             4128000000
#
#    rocksdb.compact.write.bytes  rocksdb.flush.write.bytes  rocksdb.wal.bytes  \
# 1                   3540818396                 2301488797         4128000000
# 3                  23330374011                 8996719499        16417000000
# 4                    590356007                  554189559         1056000000
# 0                    589472628                  554212973         1056000000
# 2                  20922566009                 8996726917        16417000000
# 5                   3254281401                 2263874391         4128000000
#
#    rocksdb.write.wal       WAF  latency  throughput_ops  throughput_bytes
# 1            1000000  2.415288   74.644         13396.0              52.5
# 3            1000000  2.969123  344.567          2902.0              45.4
# 4            1000000  2.083850   13.143         76087.0              75.5
# 0            1000000  2.083036   13.732         72819.0              72.2
# 2            1000000  2.822458  315.428          3170.0              49.6
# 5            1000000  2.336763   61.157         16351.0              64.1
